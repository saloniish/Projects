# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as pt
import warnings
warnings.filterwarnings('ignore')

# %%
flipkart1 = pd.read_csv('flipkart_com-ecommerce_sample.csv')
flipkart1.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
flipkart1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12211 entries, 0 to 12210
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  12211 non-null  object
#  1   crawl_timestamp          12211 non-null  object
#  2   product_url              12211 non-null  object
#  3   product_name             12211 non-null  object
#  4   product_category_tree    12211 non-null  object
#  5   pid                      12211 non-null  object
#  6   retail_price             12156 non-null  float64
#  7   discounted_price         12156 non-null  float64
#  8   image                    12208 non-null  object
#  9   is_FK_Advantage_product  12211 non-null  bool
#  10  description              12210 non-null  object
#  11  product_rating           12211 non-null  object
#  12  overall_rating           12211 non-null  object
#  13  brand                    8962 non-null   object
# ...

# %%
flipkart1.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
flipkart1.drop(['uniq_id','crawl_timestamp', 'product_url','product_category_tree',
            'image', 'is_FK_Advantage_product', 'description', 'product_rating',
       'overall_rating', 'brand', 'product_specifications'],axis=1,inplace=True)

# %%
amazon1 = pd.read_csv('amz_com-ecommerce_sample.csv', encoding= 'unicode_escape')
amazon1.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
amazon1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3629 entries, 0 to 3628
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  3629 non-null   object
#  1   crawl_timestamp          3629 non-null   object
#  2   product_url              3629 non-null   object
#  3   product_name             3628 non-null   object
#  4   product_category_tree    3628 non-null   object
#  5   pid                      3628 non-null   object
#  6   retail_price             3628 non-null   float64
#  7   discounted_price         3628 non-null   float64
#  8   image                    3628 non-null   object
#  9   is_FK_Advantage_product  3628 non-null   object
#  10  description              3627 non-null   object
#  11  product_rating           3628 non-null   object
#  12  overall_rating           3628 non-null   object
#  13  brand                    2605 non-null   object
# ...

# %%
amazon1.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
amazon1.drop(['uniq_id','crawl_timestamp', 'product_url','product_category_tree',
            'image', 'is_FK_Advantage_product', 'description', 'product_rating',
       'overall_rating', 'brand', 'product_specifications'],axis=1,inplace=True)

# %%
flipkart1
# Out:
#                                 product_name               pid  retail_price  \
# 0        Alisha Solid Women's Cycling Shorts  SRTEH2FF9KEDEFGF         999.0
# 1        FabHomeDecor Fabric Double Sofa Bed  SBEEH3QGU7MFYJFY       32157.0
# 2                                 AW Bellies  SHOEH4GRSUBJGZXE         999.0
# 3        Alisha Solid Women's Cycling Shorts  SRTEH2F6HUZMQ6SJ         699.0
# 4      Sicons All Purpose Arnica Dog Shampoo  PSOEH3ZYDMSYARJ5         220.0
# ...                                      ...               ...           ...
# 12206  Wisstler Women's Printed Casual Shirt  SHTEE4V8N7YGCJQM         999.0
# 12207      Kiosha Women's Solid Casual Shirt  SHTE9WHEXEHAQ732        1299.0
# 12208  Oxolloxo Women's Printed Casual Shirt  SHTE8GR3AJFN7SAF         749.0
# 12209  Dressberry Women's Solid Casual Shirt  SHTE63XZJFHSSEQA         999.0
# 12210  Lamora Women's Checkered Casual Shirt  SHTDZHYHJAQHGUFN         799.0
#
#        discounted_price
# ...

# %%
amazon1
# Out:
#                                    product_name               pid  \
# 0           Alisha Solid Women's Cycling Shorts  SRTEH2FF9KEDEFGF
# 1           FabHomeDecor Fabric Double Sofa Bed  SBEEH3QGU7MFYJFY
# 2                                    AW Bellies  SHOEH4GRSUBJGZXE
# 3           Alisha Solid Women's Cycling Shorts  SRTEH2F6HUZMQ6SJ
# 4         Sicons All Purpose Arnica Dog Shampoo  PSOEH3ZYDMSYARJ5
# ...                                         ...               ...
# 3624             Prithish Leo Black Ceramic Mug  MUGE9HRRKMGKHMRT
# 3625  Rajesh Digital Anniversary-56 Ceramic Mug  MUGE8VY8HZAM3ZRK
# 3626              Printland CMW1663 Ceramic Mug  MUGEACY8TXGZFHKY
# 3627   Rajesh Digital I Love You-46 Ceramic Mug  MUGE8NZC8ZHZPNFF
# 3628                                        NaN               NaN
#
#       retail_price  discounted_price
# 0            982.0             438.0
# 1          32143.0           29121.0
# 2            991.0             551.0
# ...

# %%
df=pd.concat([flipkart1, amazon1], axis=1, join="inner")         #merging the file
df
# Out:
#                                    product_name               pid  \
# 0           Alisha Solid Women's Cycling Shorts  SRTEH2FF9KEDEFGF
# 1           FabHomeDecor Fabric Double Sofa Bed  SBEEH3QGU7MFYJFY
# 2                                    AW Bellies  SHOEH4GRSUBJGZXE
# 3           Alisha Solid Women's Cycling Shorts  SRTEH2F6HUZMQ6SJ
# 4         Sicons All Purpose Arnica Dog Shampoo  PSOEH3ZYDMSYARJ5
# ...                                         ...               ...
# 3624             Prithish Leo Black Ceramic Mug  MUGE9HRRKMGKHMRT
# 3625  Rajesh Digital Anniversary-56 Ceramic Mug  MUGE8VY8HZAM3ZRK
# 3626              Printland CMW1663 Ceramic Mug  MUGEACY8TXGZFHKY
# 3627   Rajesh Digital I Love You-46 Ceramic Mug  MUGE8NZC8ZHZPNFF
# 3628             Printland PMBA1871 Ceramic Mug  MUGEBFGFM2AZHHWR
#
#       retail_price  discounted_price  \
# 0            999.0             379.0
# 1          32157.0           22646.0
# 2            999.0             499.0
# ...

# %%
df1= pd.merge(flipkart1, amazon1, on="pid")

# %%
df1.drop('pid',axis=1,inplace=True)

# %%
#renaming the file
df1.rename(columns={'product_name_x': 'Product name in Flipcart',
                    'retail_price_x': 'Retail price in Flipcart',
                     'discounted_price_x': 'Discounted price in Flipcart',
                    'product_name_y': 'Product name in Amazon',
                    'retail_price_y': 'Retail price in Amazon',
                     'discounted_price_y': 'Discounted price in Amazon',})
# Out:
#                                Product name in Flipcart  \
# 0                   Alisha Solid Women's Cycling Shorts
# 1                   FabHomeDecor Fabric Double Sofa Bed
# 2                                            AW Bellies
# 3                   Alisha Solid Women's Cycling Shorts
# 4                 Sicons All Purpose Arnica Dog Shampoo
# ...                                                 ...
# 3624  Prithish Ganpati Bappa Design5 Double Color Ce...
# 3625                     Prithish Leo Black Ceramic Mug
# 3626          Rajesh Digital Anniversary-56 Ceramic Mug
# 3627                      Printland CMW1663 Ceramic Mug
# 3628           Rajesh Digital I Love You-46 Ceramic Mug
#
#       Retail price in Flipcart  Discounted price in Flipcart  \
# 0                        999.0                         379.0
# 1                      32157.0                       22646.0
# 2                        999.0                         499.0
# ...
